# %% [markdown]
# PRODIGY_DS_04

# %%
import os
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv("twitter_training.csv")

# %%
df
# Out:
#        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# ...

# %%
col_id = ['ID', 'Brand', 'Interest', 'Content']
df = pd.read_csv('twitter_training.csv', names=col_id)

# %%
df
# Out:
#          ID        Brand  Interest  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                  Content
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
df.isnull().sum()
# Out:
# ID            0
# Brand         0
# Interest      0
# Content     686
# dtype: int64

# %%
df.dropna(axis=0 , inplace=True)

# %%
df.isnull().sum()
# Out:
# ID          0
# Brand       0
# Interest    0
# Content     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (71656, 4)

# %%
count = df['Interest'].value_counts()
count
# Out:
# Interest
# Negative      21698
# Positive      19713
# Neutral       17708
# Irrelevant    12537
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 3))
count.plot(kind='bar', color=['red', 'green', 'yellow', 'blue'])
plt.title('Interest Distribution')
plt.xlabel('Interest')
plt.ylabel('Tweets Count')
plt.xticks(rotation=0)
plt.show()

# %%
df['Brand'].count()
# Out:
# 71656

# %%
df.groupby('Brand').size()
# Out:
# Brand
# Amazon                               2249
# ApexLegends                          2278
# AssassinsCreed                       2156
# Battlefield                          2255
# Borderlands                          2206
# CS-GO                                2195
# CallOfDuty                           2314
# CallOfDutyBlackopsColdWar            2242
# Cyberpunk2077                        2175
# Dota2                                2225
# FIFA                                 2238
# Facebook                             2289
# Fortnite                             2176
# Google                               2199
# GrandTheftAuto(GTA)                  2208
# Hearthstone                          2219
# HomeDepot                            2216
# LeagueOfLegends                      2296
# MaddenNFL                            2315
# Microsoft                            2304
# NBA2K                                2299
# Nvidia                               2198
# ...

# %%
brand_data_1 = df[df['Brand'].str.contains('Microsoft', case=False)]
brand_interest_counts_1 = brand_data_1['Interest'].value_counts()
brand_interest_counts_1
# Out:
# Interest
# Neutral       816
# Negative      748
# Positive      573
# Irrelevant    167
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_interest_counts, labels=brand_interest_counts_1.index, autopct='%1.1f%%', startangle=140)
plt.title('Interst Distribution for Microsoft')
plt.show()

# %%
brand_data_2 = df[df['Brand'].str.contains('Xbox', case=False)]
brand_interest_counts_2 = brand_data_2['Interest'].value_counts()
brand_interest_counts_2
# Out:
# Interest
# Positive      743
# Irrelevant    700
# Neutral       403
# Negative      355
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_interest_counts_2, labels=brand_interest_counts_2.index, autopct='%1.1f%%', startangle=140)
plt.title('Interst Distribution for Xbox')
plt.show()

# %%
brand_data_3 = df[df['Brand'].str.contains('Nvidia', case=False)]
brand_interest_counts_3 = brand_data_3['Interest'].value_counts()
brand_interest_counts_3
# Out:
# Interest
# Neutral       848
# Positive      761
# Negative      503
# Irrelevant     86
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_interest_counts_3, labels=brand_interest_counts_3.index, autopct='%1.1f%%', startangle=140)
plt.title('Interst Distribution for Nvidia')
plt.show()

# %%
brand_data_4 = df[df['Brand'].str.contains('Fifa', case=False)]
brand_interest_counts_4 = brand_data_4['Interest'].value_counts()
brand_interest_counts_4
# Out:
# Interest
# Negative      1127
# Irrelevant     538
# Positive       473
# Neutral        100
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_interest_counts_4, labels=brand_interest_counts_4.index, autopct='%1.1f%%', startangle=140)
plt.title('Interst Distribution for Fifa')
plt.show()
